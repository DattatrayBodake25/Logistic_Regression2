# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"D:\ExcelR Pune\Data Science\DataSets\claimants.csv")

# %%
df.head()
# Out:
#    CASENUM  ATTORNEY  CLMSEX  CLMINSUR  SEATBELT  CLMAGE    LOSS
# 0        5         0     0.0       1.0       0.0    50.0  34.940
# 1        3         1     1.0       0.0       0.0    18.0   0.891
# 2       66         1     0.0       1.0       0.0     5.0   0.330
# 3       70         0     0.0       1.0       1.0    31.0   0.037
# 4       96         1     0.0       1.0       0.0    30.0   0.038

# %%
df = df.drop(columns=['CASENUM'],axis=1)

# %%
df.head()
# Out:
#    ATTORNEY  CLMSEX  CLMINSUR  SEATBELT  CLMAGE    LOSS
# 0         0     0.0       1.0       0.0    50.0  34.940
# 1         1     1.0       0.0       0.0    18.0   0.891
# 2         1     0.0       1.0       0.0     5.0   0.330
# 3         0     0.0       1.0       1.0    31.0   0.037
# 4         1     0.0       1.0       0.0    30.0   0.038

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1340 entries, 0 to 1339
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ATTORNEY  1340 non-null   int64
#  1   CLMSEX    1328 non-null   float64
#  2   CLMINSUR  1299 non-null   float64
#  3   SEATBELT  1292 non-null   float64
#  4   CLMAGE    1151 non-null   float64
#  5   LOSS      1340 non-null   float64
# dtypes: float64(5), int64(1)
# memory usage: 62.9 KB

# %%
df.dtypes
# Out:
# ATTORNEY      int64
# CLMSEX      float64
# CLMINSUR    float64
# SEATBELT    float64
# CLMAGE      float64
# LOSS        float64
# dtype: object

# %%
df[df.duplicated()].sum()
# Out:
# ATTORNEY     19.000
# CLMSEX       15.000
# CLMINSUR     26.000
# SEATBELT      0.000
# CLMAGE      204.000
# LOSS         30.224
# dtype: float64

# %%
df.describe()
# Out:
#           ATTORNEY       CLMSEX     CLMINSUR     SEATBELT       CLMAGE  \
# count  1340.000000  1328.000000  1299.000000  1292.000000  1151.000000
# mean      0.488806     0.558735     0.907621     0.017028    28.414422
# std       0.500061     0.496725     0.289671     0.129425    20.304451
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     1.000000     0.000000     9.000000
# 50%       0.000000     1.000000     1.000000     0.000000    30.000000
# 75%       1.000000     1.000000     1.000000     0.000000    43.000000
# max       1.000000     1.000000     1.000000     1.000000    95.000000
#
#               LOSS
# count  1340.000000
# mean      3.806307
# std      10.636903
# min       0.000000
# 25%       0.400000
# 50%       1.069500
# 75%       3.781500
# max     173.604000

# %%
sns.heatmap(df)
# Out:
# <Axes: >

# %%
df.isna().sum()
# Out:
# ATTORNEY      0
# CLMSEX       12
# CLMINSUR     41
# SEATBELT     48
# CLMAGE      189
# LOSS          0
# dtype: int64

# %%
df.hist()
plt.tight_layout()

# %%
#Filling null values

# %%
df['CLMSEX'].fillna(df['CLMSEX'].mode()[0],inplace=True)

# %%
df['CLMINSUR'].fillna(df['CLMINSUR'].mode()[0],inplace=True)

# %%
df['SEATBELT'].fillna(df['SEATBELT'].mode()[0],inplace=True)

# %%
df['CLMAGE'].fillna(df['CLMAGE'].mode()[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# ATTORNEY    0
# CLMSEX      0
# CLMINSUR    0
# SEATBELT    0
# CLMAGE      0
# LOSS        0
# dtype: int64

# %% [raw]
#                                   OR

# %%
# from sklearn.impute import SimpleImputer

# %%
# si = SimpleImputer(strategy ='most_frequent' )

# %%
# df.loc[:'CLMINSUR':'CLMAGE'] = si.fit_transform(df.loc[:'CLMINSUR':'CLMAGE'])

# %%
#see all rows
pd.set_option('display.max_rows',None)

# %%
df
# Out:
#       ATTORNEY  CLMSEX  CLMINSUR  SEATBELT  CLMAGE     LOSS
# 0            0     0.0       1.0       0.0    50.0   34.940
# 1            1     1.0       0.0       0.0    18.0    0.891
# 2            1     0.0       1.0       0.0     5.0    0.330
# 3            0     0.0       1.0       1.0    31.0    0.037
# 4            1     0.0       1.0       0.0    30.0    0.038
# 5            0     1.0       1.0       0.0    35.0    0.309
# 6            0     0.0       1.0       0.0     9.0    3.538
# 7            0     1.0       1.0       0.0    34.0    4.881
# 8            1     1.0       1.0       0.0    60.0    0.874
# 9            1     0.0       1.0       0.0    10.0    0.350
# 10           0     1.0       1.0       0.0    37.0    6.190
# 11           0     0.0       1.0       0.0    41.0   19.610
# 12           1     0.0       1.0       0.0     7.0    1.678
# 13           0     1.0       1.0       0.0    40.0    0.673
# 14           1     1.0       1.0       0.0    37.0    0.143
# ...

# %%
df.duplicated().sum()
# Out:
# 33

# %%
pd.set_option('display.max_rows',False)

# %%
df1 = df.drop_duplicates()

# %%
df1
# Out:
#       ATTORNEY  CLMSEX  CLMINSUR  SEATBELT  CLMAGE    LOSS
# 0            0     0.0       1.0       0.0    50.0  34.940
# 1            1     1.0       0.0       0.0    18.0   0.891
# 2            1     0.0       1.0       0.0     5.0   0.330
# 3            0     0.0       1.0       1.0    31.0   0.037
# 4            1     0.0       1.0       0.0    30.0   0.038
# 5            0     1.0       1.0       0.0    35.0   0.309
# 6            0     0.0       1.0       0.0     9.0   3.538
# 7            0     1.0       1.0       0.0    34.0   4.881
# 8            1     1.0       1.0       0.0    60.0   0.874
# 9            1     0.0       1.0       0.0    10.0   0.350
# 10           0     1.0       1.0       0.0    37.0   6.190
# 11           0     0.0       1.0       0.0    41.0  19.610
# ...        ...     ...       ...       ...     ...     ...
# 1328         0     0.0       1.0       0.0    14.0   0.400
# 1329         1     1.0       1.0       0.0    33.0   0.535
# ...

# %%
#splitting Data

# %%
from sklearn.model_selection import train_test_split

# %%
X = df1.iloc[:,1:]
y = df1['ATTORNEY']

# %%
X
# Out:
#       CLMSEX  CLMINSUR  SEATBELT  CLMAGE    LOSS
# 0        0.0       1.0       0.0    50.0  34.940
# 1        1.0       0.0       0.0    18.0   0.891
# 2        0.0       1.0       0.0     5.0   0.330
# 3        0.0       1.0       1.0    31.0   0.037
# 4        0.0       1.0       0.0    30.0   0.038
# 5        1.0       1.0       0.0    35.0   0.309
# 6        0.0       1.0       0.0     9.0   3.538
# 7        1.0       1.0       0.0    34.0   4.881
# 8        1.0       1.0       0.0    60.0   0.874
# 9        0.0       1.0       0.0    10.0   0.350
# 10       1.0       1.0       0.0    37.0   6.190
# 11       0.0       1.0       0.0    41.0  19.610
# ...      ...       ...       ...     ...     ...
# 1328     0.0       1.0       0.0    14.0   0.400
# 1329     1.0       1.0       0.0    33.0   0.535
# 1330     0.0       1.0       0.0    33.0   6.817
# 1331     1.0       1.0       0.0     3.0   0.950
# 1332     1.0       1.0       0.0     9.0   0.000
# ...

# %%
y
# Out:
# 0       0
# 1       1
# 2       1
# 3       0
# 4       1
# 5       0
# 6       0
# 7       0
# 8       1
# 9       1
# 10      0
# 11      0
# 12      1
# 13      0
# 14      1
#        ..
# 1325    0
# 1326    0
# 1327    0
# 1328    0
# 1329    1
# 1330    1
# 1331    0
# 1332    1
# 1333    1
# 1334    1
# 1335    1
# 1336    0
# 1337    1
# 1338    0
# 1339    1
# Name: ATTORNEY, Length: 1307, dtype: int64

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=0.25,random_state=1)

# %%
X_train.shape
# Out:
# (326, 5)

# %%
X_test.shape
# Out:
# (981, 5)

# %%
y_train.shape
# Out:
# (326,)

# %%
y_test.shape
# Out:
# (981,)

# %% [markdown]
# # Model Building

# %%
#Feature scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
X_train = sc.fit_transform(X_train)

# %%
X_test = sc.fit_transform(X_test)

# %%
X.columns
# Out:
# Index(['CLMSEX', 'CLMINSUR', 'SEATBELT', 'CLMAGE', 'LOSS'], dtype='object')

# %%
pd.DataFrame(X_train,columns=X.columns)
# Out:
#        CLMSEX  CLMINSUR  SEATBELT    CLMAGE      LOSS
# 0    0.934646  0.300501 -0.096374 -0.616603  0.281960
# 1    0.934646  0.300501 -0.096374 -0.993032 -0.452183
# 2   -1.069924  0.300501 -0.096374 -0.381336  0.185795
# 3   -1.069924  0.300501 -0.096374  2.630091  1.968389
# 4   -1.069924  0.300501 -0.096374 -0.804818 -0.233638
# 5   -1.069924  0.300501 -0.096374 -0.851871 -0.227486
# 6    0.934646  0.300501 -0.096374 -0.428389  0.375316
# 7    0.934646  0.300501 -0.096374  0.606789 -0.043315
# 8   -1.069924 -3.327773 -0.096374 -1.040085 -0.323918
# 9   -1.069924  0.300501 -0.096374 -0.804818 -0.453119
# 10   0.934646  0.300501 -0.096374 -0.804818  0.014464
# 11   0.934646  0.300501 -0.096374  0.371521 -0.226149
# ..        ...       ...       ...       ...       ...
# 314 -1.069924  0.300501 -0.096374  0.889110 -0.211971
# 315  0.934646  0.300501 -0.096374 -0.898925 -0.040908
# 316  0.934646  0.300501 -0.096374 -0.804818  0.808392
# ...

# %%
from sklearn.linear_model import LogisticRegression

# %%
Lr = LogisticRegression()

# %%
Lr.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
result1 = (Lr.score(X_train, y_train)*100)
result2 = (Lr.score(X_test, y_test)*100)

# %%
print("Training Accuracy is: ",result1)
print()
# Out:
# Training Accuracy is:  67.17791411042946

# %%
print("Testing Accuracy is: ",result2)
print()
# Out:
# Testing Accuracy is:  63.20081549439348

# %%
y_pred = Lr.predict(X_test)

# %%
from sklearn import metrics
from sklearn.metrics import r2_score,mean_squared_error

# %%
mse = metrics.mean_squared_error(y_test, y_pred)
mae = metrics.mean_absolute_error(y_test, y_pred)
r2_score = metrics.r2_score(y_test, y_pred)
rmse = np.sqrt(mse)
print('Mean Squared Error: ',mse)
print()
print('Mean Absolute Error: ',mae)
print()
print('Root Mean Squared Error: ',rmse)
print()
print('r2_score: ',r2_score)
# Out:
# Mean Squared Error:  0.36799184505606525
#
# Mean Absolute Error:  0.36799184505606525
#
# Root Mean Squared Error:  0.6066233139733959
#
# r2_score:  -0.4726422155688623

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[367, 134],
#        [227, 253]], dtype=int64)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.73      0.67       501
#            1       0.65      0.53      0.58       480
#
#     accuracy                           0.63       981
#    macro avg       0.64      0.63      0.63       981
# weighted avg       0.64      0.63      0.63       981

# %%
#link for Classification report
#https://towardsdatascience.com/a-look-at-precision-recall-and-f1-score-36b5fd0dd3ec

# %% [markdown]
# # Thank You!
